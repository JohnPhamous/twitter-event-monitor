# %%
import pandas as pd
import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tweets = pd.read_csv('./csta.csv', names=['date', 'tweet'], encoding='utf8')

# %%
tweets['date'] = pd.to_datetime(tweets['date'])
tweets['tweet'] = tweets['tweet'].astype(str)

# %%
retweets = tweets[tweets['tweet'].str.contains('RT')]

# %%
tweets['is_retweet'] = tweets['tweet'].apply(lambda t: t if 'RT' in t else 0)

# %%
new_col = []
for tweet in tweets['is_retweet']:
    if tweet is not 0:
        new_col.append('Retweet')
    else:
        new_col.append('Original')
tweets['is_retweet'] = new_col

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="is_retweet", data=tweets, )
ax.set_title('#CSTA2018 Retweets vs. Unique (July 10, 2018 10:11AM)')
ax.set_xlabel('Type of Tweet')
ax.set_ylabel('Number of Tweets')
figure = ax.get_figure()
figure.savefig('retweets.jpg')

# %%
time_series = tweets.groupby(
    [pd.Grouper(key='date',freq='H')]
).size().reset_index(name='count')

# %%
time_series
# Out:
#                    date  count
# 0   2018-06-29 14:00:00      3
# 1   2018-06-29 15:00:00      3
# 2   2018-06-29 16:00:00      4
# 3   2018-06-29 17:00:00      1
# 4   2018-06-29 18:00:00      2
# 5   2018-06-29 19:00:00      2
# 6   2018-06-29 20:00:00      4
# 7   2018-06-29 21:00:00      0
# 8   2018-06-29 22:00:00      6
# 9   2018-06-29 23:00:00      0
# 10  2018-06-30 00:00:00      0
# 11  2018-06-30 01:00:00      6
# 12  2018-06-30 02:00:00      0
# 13  2018-06-30 03:00:00      2
# 14  2018-06-30 04:00:00      2
# 15  2018-06-30 05:00:00      0
# 16  2018-06-30 06:00:00      0
# 17  2018-06-30 07:00:00      0
# 18  2018-06-30 08:00:00      0
# 19  2018-06-30 09:00:00      0
# 20  2018-06-30 10:00:00      0
# 21  2018-06-30 11:00:00      2
# 22  2018-06-30 12:00:00      0
# 23  2018-06-30 13:00:00     26
# 24  2018-06-30 14:00:00     14
# 25  2018-06-30 15:00:00      2
# 26  2018-06-30 16:00:00      2
# 27  2018-06-30 17:00:00      0
# 28  2018-06-30 18:00:00      2
# 29  2018-06-30 19:00:00      2
# ..                  ...    ...
# 236 2018-07-09 10:00:00     16
# 237 2018-07-09 11:00:00     40
# 238 2018-07-09 12:00:00     55
# 239 2018-07-09 13:00:00    199
# 240 2018-07-09 14:00:00    194
# 241 2018-07-09 15:00:00    120
# 242 2018-07-09 16:00:00    128
# 243 2018-07-09 17:00:00    105
# 244 2018-07-09 18:00:00    157
# 245 2018-07-09 19:00:00    109
# 246 2018-07-09 20:00:00    144
# 247 2018-07-09 21:00:00    119
# 248 2018-07-09 22:00:00     75
# 249 2018-07-09 23:00:00     66
# 250 2018-07-10 00:00:00     48
# 251 2018-07-10 01:00:00     55
# 252 2018-07-10 02:00:00     87
# 253 2018-07-10 03:00:00     24
# 254 2018-07-10 04:00:00     15
# 255 2018-07-10 05:00:00     11
# 256 2018-07-10 06:00:00     14
# 257 2018-07-10 07:00:00      6
# 258 2018-07-10 08:00:00     13
# 259 2018-07-10 09:00:00      3
# 260 2018-07-10 10:00:00      9
# 261 2018-07-10 11:00:00     10
# 262 2018-07-10 12:00:00     39
# 263 2018-07-10 13:00:00    178
# 264 2018-07-10 14:00:00    149
# 265 2018-07-10 15:00:00     10
#
# [266 rows x 2 columns]

# %%
ax = time_series.plot(x='date', y='count', figsize=(20, 7))
ax.axvline(x='2018-07-07 10:00:00', color='red', label='Start')
ax.text(x='2018-07-07 12:30:00', y=150, s='CSTA Start', fontsize=20)
ax.axvline(x='2018-07-09 07:30:00', color='green', label='Start')
ax.text(x='2018-07-09 08:30:00', y=225, s='Keynote', fontsize=20)
sns.set_style('darkgrid')
ax.set_title('Twitter Activity by Time (Up to July 10 10:11AM)', fontSize=30)
ax.set_xlabel('Day and Hour', fontSize=20)
ax.set_ylabel('Number of Tweets', fontSize=20)
ax.tick_params(labelsize=20, axis='both')
figure = ax.get_figure()
figure.savefig('timeseries.jpg')
# plt.show()

# %% [markdown]
# ## Word Frequencies

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

# %%
# nltk dependencies needed for tokenizing and removing stop words
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/jp218s/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jp218s/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
word_frequencies = {}
stop_words = set(stopwords.words('english'))
manual_stop_words = ('rt', 'if', 'like', 'https', 'co', 'csta2018')

for word in manual_stop_words:
    stop_words.add(word)

tokenizer = RegexpTokenizer(r'\w+')

tokens = []

for index, row in tweets.iterrows():
    current_tokens = tokenizer.tokenize(row['tweet'].lower())
    for token in current_tokens:
        tokens.append(token)
# tokens = tokenizer.tokenize(tweets['tweet'].iloc[0])

filtered_tokens = [w for w in tokens if not w in stop_words]

# %%
import collections

counter = collections.Counter(filtered_tokens)

# %%
clean_tokens = []

for word in tokens:
    if len(word) != 10:
        clean_tokens.append(word)
filtered_tokens = [w for w in clean_tokens if not w in stop_words]

# %%
filtered_tokens
# Out:
# ['csatellis',
#  'function',
#  'ordering',
#  'meal',
#  'api',
#  'menu',
#  'googleedu',
#  'codesparkapp',
#  'happen',
#  'omaha',
#  'nebraska',
#  'swing',
#  'booth',
#  '22',
#  'spin',
#  'wheel',
#  'win',
#  'prizes',
#  'olk',
#  'robotgarden',
#  'ready',
#  'booth',
#  '45',
#  'come',
#  'visit',
#  'afternoon',
#  'exhibit',
#  'hall',
#  'opens',
#  '1',
#  'hummingbirdbit',
#  'cst',
#  'codesparkapp',
#  'glitch',
#  'arrived',
#  'loves',
#  'meeting',
#  'computer',
#  'science',
#  'educators',
#  'swing',
#  'codesparkapp',
#  'booth',
#  '22',
#  'say',
#  'breastfeeding',
#  'breastfeedinginpublic',
#  'surprise',
#  'anything',
#  'legaldeathcult',
#  'shock',
#  'many',
#  'good',
#  'cs',
#  'convos',
#  'happening',
#  'using',
#  'workshop',
#  'find',
#  'exactly',
#  'right',
#  'love',
#  'well',
#  'maps',
#  'f',
#  'function',
#  'ordering',
#  'meal',
#  'api',
#  'menu',
#  'googleedu',
#  'mberry',
#  'function',
#  'block',
#  'code',
#  'use',
#  'knowing',
#  'name',
#  'need',
#  'know',
#  'works',
#  'abstraction',
#  'clcsimon',
#  'new',
#  'physical',
#  'computing',
#  'guides',
#  'microbit',
#  'gt',
#  'gt',
#  'includes',
#  'leds',
#  'inc',
#  'rgb',
#  'potentiometer',
#  'push',
#  'lisastebs',
#  'best',
#  'new',
#  'connections',
#  'dinnerfun',
#  'stickerswag',
#  'function',
#  'block',
#  'code',
#  'use',
#  'knowing',
#  'name',
#  'need',
#  'know',
#  'works',
#  'abstraction',
#  'zamansky',
#  'found',
#  'repping',
#  'bootstrapworld',
#  'repping',
#  'githubeducation',
#  'good',
#  'times',
#  'cs',
#  'teacher',
#  'ambassadors',
#  'hard',
#  'work',
#  'making',
#  'plans',
#  'great',
#  'year',
#  'stayed',
#  'tuned',
#  'hey',
#  'mrgbulldogs',
#  'really',
#  'check',
#  'pgliljedahl',
#  'work',
#  'building',
#  'thinking',
#  'amp',
#  'wipebook',
#  'please',
#  'come',
#  'booth',
#  'join',
#  'community',
#  'resources',
#  'support',
#  'grade',
#  'levels',
#  'cs',
#  'education',
#  'mberry',
#  'inspiring',
#  'start',
#  'googleforedu',
#  'machine',
#  'learning',
#  'workshop',
#  'abu',
#  'story',
#  'get',
#  'learn',
#  'enough',
#  'coding',
#  'alice',
#  'oracleacademy',
#  'workshop',
#  'anoth',
#  'clcsimon',
#  'new',
#  'physical',
#  'computing',
#  'guides',
#  'microbit',
#  'gt',
#  'gt',
#  'includes',
#  'leds',
#  'inc',
#  'rgb',
#  'potentiometer',
#  'push',
#  'firialabs',
#  'new',
#  'edtech',
#  'startup',
#  'great',
#  'hear',
#  'everyone',
#  'talking',
#  'iste18',
#  'python',
#  'diane_levitt',
#  'working',
#  'equity',
#  'csforall',
#  'reading',
#  'kamaubobb',
#  'start',
#  'keep',
#  'going',
#  'ht',
#  'come',
#  'say',
#  'hi',
#  'booth',
#  'codehs',
#  'happy',
#  'answer',
#  'questions',
#  'love',
#  'great',
#  'way',
#  'show',
#  'students',
#  'power',
#  'cloud',
#  'computing',
#  'bigdata',
#  'codesparkapp',
#  'glitch',
#  'arrived',
#  'loves',
#  'meeting',
#  'computer',
#  'science',
#  'educators',
#  'swing',
#  'codesparkapp',
#  'booth',
#  '22',
#  'say',
#  'googleforedu',
#  'great',
#  'meeting',
#  'iste2018',
#  'nice',
#  'seeing',
#  'clcsimon',
#  'new',
#  'physical',
#  'computing',
#  'guides',
#  'microbit',
#  'gt',
#  'gt',
#  'includes',
#  'leds',
#  'inc',
#  'rgb',
#  'potentiometer',
#  'push',
#  'clcsimon',
#  'new',
#  'physical',
#  'computing',
#  'guides',
#  'microbit',
#  'gt',
#  'gt',
#  'includes',
#  'leds',
#  'inc',
#  'rgb',
#  'potentiometer',
#  'push',
#  'found',
#  'repping',
#  'bootstrapworld',
#  'repping',
#  'githubeducation',
#  'good',
#  'times',
#  'lesson',
#  'plans',
#  'already',
#  'created',
#  'first',
#  'weeks',
#  'k',
#  '5',
#  'tech',
#  'class',
#  'lit',
#  'integration',
#  'thanks',
#  'todd_lash',
#  'visionsbyvic',
#  'interesting',
#  'learn',
#  'programming',
#  'alice',
#  'eric',
#  'brown',
#  'carnegie',
#  'mellon',
#  'yep',
#  'lesson',
#  'plans',
#  'already',
#  'created',
#  'first',
#  'weeks',
#  'k',
#  '5',
#  'tech',
#  'class',
#  'lit',
#  'integration',
#  'thanks',
#  'todd_lash',
#  'visionsbyvic',
#  'online',
#  'resources',
#  'coding',
#  'students',
#  'stop',
#  'booth',
#  '21',
#  'learn',
#  'mindtap',
#  'help',
#  'yo',
#  'mberry',
#  'google',
#  'translate',
#  'getting',
#  'good',
#  'googleforedu',
#  'workshop',
#  'excited',
#  'try',
#  'interactive',
#  'story',
#  'telling',
#  'w',
#  'unfold',
#  'studio',
#  'thanks',
#  'sharing',
#  'awesome',
#  'morning',
#  'learning',
#  'vr',
#  'using',
#  'glitch',
#  'aframevr',
#  'build',
#  'vr',
#  'app',
#  'using',
#  'tell',
#  'pizza',
#  'googleforedu',
#  'k',
#  '12',
#  'cs',
#  'framework',
#  'states',
#  'practice',
#  '1',
#  'fostering',
#  'inclusive',
#  'computing',
#  'culture',
#  'students',
#  'see',
#  'inspiredtoteach',
#  'fgmart',
#  'ireneannelee',
#  'csteachersorg',
#  'jovialjoy',
#  'nytimes',
#  'ajlunited',
#  'love',
#  'sound',
#  'mis',
#  'tliandrew',
#  'morning',
#  'things',
#  'graphing',
#  'circuitplayground',
#  'accelerometer',
#  'adafruit',
#  'neopixel',
#  'strip',
#  'csta201',
#  'glitch',
#  'arrived',
#  'loves',
#  'meeting',
#  'computer',
#  'science',
#  'educators',
#  'swing',
#  'codesparkapp',
#  'booth',
#  '22',
#  'lesson',
#  'plans',
#  'already',
#  'created',
#  'first',
#  'weeks',
#  'k',
#  '5',
#  'tech',
#  'class',
#  'lit',
#  'integration',
#  'thanks',
#  'todd_lash',
#  'j_alano',
#  'great',
#  'session',
#  'czajka_sandy',
#  'crystallfurman',
#  'objects',
#  'always',
#  'looking',
#  'new',
#  'resources',
#  'help',
#  'students',
#  'great',
#  'workshop',
#  'snap',
#  'based',
#  'allows',
#  'students',
#  'learn',
#  'distributed',
#  'programming',
#  'best',
#  'new',
#  'connections',
#  'dinnerfun',
#  'stickerswag',
#  'diane_levitt',
#  'working',
#  'equity',
#  'csforall',
#  'reading',
#  'kamaubobb',
#  'start',
#  'keep',
#  'going',
#  'ht',
#  'firialabs',
#  'new',
#  'edtech',
#  'startup',
#  'great',
#  'hear',
#  'everyone',
#  'talking',
#  'iste18',
#  'python',
#  'aderbenwick',
#  'cseducation',
#  'teacher',
#  'teaching',
#  'kids',
#  'data',
#  'check',
#  'oracle',
#  'dev',
#  'gym',
#  'free',
#  'btwarek',
#  'pumped',
#  'workshop',
#  'billmarsland',
#  'todd_lash',
#  'visionsbyvicky',
#  'cs',
#  'literacy',
#  'amazing',
#  'learning',
#  'cs',
#  'aderbenwick',
#  'cool',
#  'oracleacademy',
#  'workshop',
#  'attendees',
#  'got',
#  'sneak',
#  'preview',
#  'new',
#  'resources',
#  'coming',
#  'fall',
#  'miss',
#  'cseducation',
#  'teacher',
#  'teaching',
#  'kids',
#  'data',
#  'check',
#  'oracle',
#  'dev',
#  'gym',
#  'diane_levitt',
#  'super',
#  'excited',
#  'panel',
#  'cs',
#  'content',
#  'coaching',
#  'monday',
#  '11',
#  '15',
#  'room',
#  '210',
#  'learn',
#  'come',
#  'say',
#  'hi',
#  'googleforedu',
#  'booth',
#  'afternoon',
#  'tomorrow',
#  'new',
#  'edtech',
#  'startup',
#  'great',
#  'hear',
#  'everyone',
#  'talking',
#  'iste18',
#  'python',
#  'greenescience',
#  'watershed',
#  'moment',
#  'computer',
#  'science',
#  'education',
#  'chris',
#  'jakebask',
#  'google',
#  'reception',
#  'derekbabb',
#  'hey',
#  'attendees',
#  'made',
#  'fun',
#  'sheet',
#  'people',
#  'things',
#  'omaha',
#  'csteachersorg',
#  'c',
#  'clcsimon',
#  'new',
#  'physical',
#  'computing',
#  'guides',
#  'microbit',
#  'gt',
#  'gt',
#  'includes',
#  'leds',
#  'inc',
#  'rgb',
#  'potentiometer',
#  'push',
#  'debrajacoby',
#  'resources',
#  'amazing',
#  'session',
#  'missing',
#  'billmarsland',
#  'jigsawing',
#  'writing',
#  'standards',
#  'aligned',
#  'lesson',
#  'plans',
#  'based',
#  'cs',
#  'concepts',
#  'book',
#  'code',
#  'edtech',
#  'microbit',
#  'graduatefromblocks',
#  'codespace',
#  'coding',
#  'csforall',
#  'csk8',
#  'map',
#  'app',
#  'using',
#  'zoom',
#  'pan',
#  'give',
#  'city',
#  'name',
#  'weather',
#  'many',
#  'possibilities',
#  'f',
#  'super',
#  'excited',
#  'panel',
#  'cs',
#  'content',
#  'coaching',
#  'monday',
#  '11',
#  '15',
#  'room',
#  '210',
#  'learn',
#  'mberry',
#  'google',
#  'translate',
#  'getting',
#  'good',
#  'googleforedu',
#  'workshop',
#  'first',
#  'machine',
#  'learning',
#  'program',
#  'using',
#  'scratch',
#  'using',
#  'workshop',
#  'works',
#  'csforall',
#  'csk8',
#  'codehs',
#  'csta',
#  'omaha',
#  'today',
#  'swing',
#  'booth',
#  'meet',
#  'lea',
#  'evelyn',
#  'team',
#  'readwritecode',
#  'teachmecs',
#  'created',
#  'supersad',
#  'instance',
#  'emoji',
#  'class',
#  'check',
#  'newest',
#  'integration',
#  'google',
#  'classroom',
#  'even',
#  'easier',
#  'set',
#  'codehs',
#  'class',
#  'studen',
#  'jakebask',
#  'wrapped',
#  'amazing',
#  'summit',
#  '70',
#  'chapter',
#  'leaders',
#  'across',
#  'us',
#  'proud',
#  'work',
#  'teachers',
#  'cool',
#  'oracleacademy',
#  'workshop',
#  'attendees',
#  'got',
#  'sneak',
#  'preview',
#  'new',
#  'resources',
#  'coming',
#  'fall',
#  'leslie',
#  'keller',
#  'aced',
#  'python',
#  'microsoftmta',
#  'another',
#  'person',
#  'passes',
#  'certification',
#  'passedmymta',
#  'created',
#  'supersad',
#  'instance',
#  'emoji',
#  'class',
#  'codesparkapp',
#  'happen',
#  'omaha',
#  'nebraska',
#  'swing',
#  'booth',
#  '22',
#  'spin',
#  'wheel',
#  'win',
#  'prizes',
#  'olk',
#  'working',
#  'equity',
#  'csforall',
#  'reading',
#  'kamaubobb',
#  'start',
#  'keep',
#  'going',
#  'addicting',
#  'play',
#  'machine',
#  'learning',
#  'check',
#  'observation',
#  'oracleacademy',
#  'workshop',
#  'students',
#  'need',
#  'data',
#  'emph',
#  'codehs',
#  'csta',
#  'omaha',
#  'today',
#  'swing',
#  'booth',
#  'meet',
#  'lea',
#  'evelyn',
#  'team',
#  'readwritecode',
#  'codehs',
#  'stop',
#  'codehs',
#  'booth',
#  'codesparkapp',
#  'happen',
#  'omaha',
#  'nebraska',
#  'swing',
#  'booth',
#  '22',
#  'spin',
#  'wheel',
#  'win',
#  'prizes',
#  'olk',
#  'jigsawing',
#  'writing',
#  'standards',
#  'aligned',
#  'lesson',
#  'plans',
#  'based',
#  'cs',
#  'concepts',
#  'book',
#  'code',
#  'sandcas',
#  'taegot',
#  'codenewbies',
#  'a2',
#  'week',
#  'attending',
#  'omaha',
#  'goal',
#  'gain',
#  'new',
#  'skills',
#  'applied',
#  'toolki',
#  'google',
#  'translate',
#  'getting',
#  'good',
#  'googleforedu',
#  'workshop',
#  'firialabs',
#  'hey',
#  'visit',
#  'firialabs',
#  'booth',
#  'would',
#  'share',
#  'contact',
#  'information',
#  'us',
#  'please',
#  'btwarek',
#  'pumped',
#  'workshop',
#  'billmarsland',
#  'todd_lash',
#  'visionsbyvicky',
#  'cs',
#  'literacy',
#  'amazing',
#  'learning',
#  'cs',
#  'nailed',
#  'zamansky',
#  'kids',
#  'left',
#  'came',
#  'great',
#  'job',
#  'deserve',
#  'congratul',
#  'happen',
#  'omaha',
#  'nebraska',
#  'swing',
#  'booth',
#  '22',
#  'spin',
#  'wheel',
#  'win',
#  'prizes',
#  'firialabs',
#  'hey',
#  'visit',
#  'firialabs',
#  'booth',
#  'would',
#  'share',
#  'contact',
#  'information',
#  'us',
#  'please',
#  'firialabs',
#  'm4ttbit',
#  'great',
#  'meet',
#  'looking',
#  'python',
#  'graduatefromblocks',
#  'edtech',
#  'microbit',
#  'firial',
#  'clcsimon',
#  'new',
#  'physical',
#  'computing',
#  'guides',
#  'microbit',
#  'gt',
#  'gt',
#  'includes',
#  'leds',
#  'inc',
#  'rgb',
#  'potentiometer',
#  'push',
#  'awesome',
#  'see',
#  'mrtomocon',
#  'weareci',
#  'action',
#  'computer',
#  'science',
#  'education',
#  'students',
#  'stop',
#  'st',
#  'scholastica',
#  'booth',
#  '36',
#  'monday',
#  '2',
#  '15',
#  'meet',
#  'greet',
#  'spent',
#  'morning',
#  'creating',
#  'first',
#  '3d',
#  'vr',
#  'program',
#  'using',
#  'aframevr',
#  'glitch',
#  'threejs',
#  'npmjs',
#  'gr8',
#  'clcsimon',
#  'new',
#  'physical',
#  'computing',
#  'guides',
#  'microbit',
#  'gt',
#  'gt',
#  'includes',
#  'leds',
#  'inc',
#  'rgb',
#  'potentiometer',
#  'push',
#  'great',
#  'session',
#  'czajka_sandy',
#  'crystallfurman',
#  'objects',
#  'always',
#  'looking',
#  'new',
#  'resources',
#  'help',
#  'stu',
#  'bruce',
#  'philly',
#  'passedmymta',
#  'block',
#  'based',
#  'programming',
#  'stop',
#  'room',
#  '202',
#  'try',
#  'free',
#  'cer',
#  'btwarek',
#  'pumped',
#  'workshop',
#  'billmarsland',
#  'todd_lash',
#  'visionsbyvicky',
#  'cs',
#  'literacy',
#  'amazing',
#  'learning',
#  'cs',
#  'launchcompsci',
#  'infusing',
#  'literacy',
#  'k',
#  '5',
#  'classroom',
#  'using',
#  'cs',
#  'excited',
#  'hear',
#  'todd_lash',
#  'billmarsland',
#  'visionsbyvicky',
#  'oracleacademy',
#  'workshop',
#  'getting',
#  'started',
#  'learning',
#  'quick',
#  'sql',
#  'csta',
#  'omaha',
#  'today',
#  'swing',
#  'booth',
#  'meet',
#  'lea',
#  'evelyn',
#  'team',
#  'readwritecode',
#  'spent',
#  'morning',
#  'creating',
#  'first',
#  '3d',
#  'vr',
#  'program',
#  'using',
#  'aframevr',
#  'glitch',
#  'threejs',
#  'npmjs',
#  'gr8',
#  'first',
#  'machine',
#  'learning',
#  'program',
#  'using',
#  'scratch',
#  'using',
#  'workshop',
#  'works',
#  'csforall',
#  'csk8',
#  'anyone',
#  'else',
#  ...]

# %%
counter = collections.Counter(filtered_tokens)

# %%
counter
# Out:
# Counter({'csatellis': 10,
#          'function': 17,
#          'ordering': 8,
#          'meal': 8,
#          'api': 12,
#          'menu': 8,
#          'googleedu': 11,
#          'codesparkapp': 56,
#          'happen': 17,
#          'omaha': 374,
#          'nebraska': 78,
#          'swing': 54,
#          'booth': 257,
#          '22': 32,
#          'spin': 16,
#          'wheel': 16,
#          'win': 18,
#          'prizes': 16,
#          'olk': 13,
#          'robotgarden': 21,
#          'ready': 121,
#          '45': 17,
#          'come': 199,
#          'visit': 54,
#          'afternoon': 47,
#          'exhibit': 27,
#          'hall': 29,
#          'opens': 20,
#          '1': 55,
#          'hummingbirdbit': 21,
#          'cst': 33,
#          'glitch': 48,
#          'arrived': 23,
#          'loves': 14,
#          'meeting': 40,
#          'computer': 471,
#          'science': 452,
#          'educators': 139,
#          'say': 119,
#          'breastfeeding': 1,
#          'breastfeedinginpublic': 1,
#          'surprise': 1,
#          'anything': 4,
#          'legaldeathcult': 1,
#          'shock': 1,
#          'many': 107,
#          'good': 80,
#          'cs': 714,
#          'convos': 3,
#          'happening': 6,
#          'using': 356,
#          'workshop': 250,
#          'find': 62,
#          'exactly': 15,
#          'right': 59,
#          'love': 142,
#          'well': 67,
#          'maps': 11,
#          'f': 40,
#          'mberry': 104,
#          'block': 42,
#          'code': 91,
#          'use': 90,
#          'knowing': 9,
#          'name': 22,
#          'need': 74,
#          'know': 93,
#          'works': 85,
#          'abstraction': 13,
#          'clcsimon': 57,
#          'new': 351,
#          'physical': 102,
#          'computing': 176,
#          'guides': 60,
#          'microbit': 115,
#          'gt': 130,
#          'includes': 62,
#          'leds': 60,
#          'inc': 61,
#          'rgb': 60,
#          'potentiometer': 60,
#          'push': 62,
#          'lisastebs': 12,
#          'best': 74,
#          'connections': 10,
#          'dinnerfun': 6,
#          'stickerswag': 22,
#          'zamansky': 15,
#          'found': 20,
#          'repping': 8,
#          'bootstrapworld': 90,
#          'githubeducation': 4,
#          'times': 6,
#          'teacher': 218,
#          'ambassadors': 7,
#          'hard': 22,
#          'work': 104,
#          'making': 40,
#          'plans': 31,
#          'great': 368,
#          'year': 114,
#          'stayed': 1,
#          'tuned': 3,
#          'hey': 176,
#          'mrgbulldogs': 13,
#          'really': 55,
#          'check': 159,
#          'pgliljedahl': 7,
#          'building': 42,
#          'thinking': 124,
#          'amp': 279,
#          'wipebook': 7,
#          'please': 36,
#          'join': 63,
#          'community': 79,
#          'resources': 147,
#          'support': 86,
#          'grade': 12,
#          'levels': 8,
#          'education': 144,
#          'inspiring': 30,
#          'start': 84,
#          'googleforedu': 109,
#          'machine': 134,
#          'learning': 376,
#          'abu': 13,
#          'story': 34,
#          'get': 148,
#          'learn': 211,
#          'enough': 6,
#          'coding': 98,
#          'alice': 12,
#          'oracleacademy': 54,
#          'anoth': 3,
#          'firialabs': 124,
#          'edtech': 37,
#          'startup': 13,
#          'hear': 31,
#          'everyone': 65,
#          'talking': 34,
#          'iste18': 14,
#          'python': 83,
#          'diane_levitt': 90,
#          'working': 76,
#          'equity': 31,
#          'csforall': 264,
#          'reading': 15,
#          'kamaubobb': 11,
#          'keep': 32,
#          'going': 83,
#          'ht': 13,
#          'hi': 54,
#          'codehs': 87,
#          'happy': 36,
#          'answer': 48,
#          'questions': 72,
#          'way': 127,
#          'show': 16,
#          'students': 192,
#          'power': 11,
#          'cloud': 7,
#          'bigdata': 4,
#          'iste2018': 6,
#          'nice': 20,
#          'seeing': 18,
#          'lesson': 37,
#          'already': 54,
#          'created': 97,
#          'first': 179,
#          'weeks': 16,
#          'k': 195,
#          '5': 88,
#          'tech': 44,
#          'class': 119,
#          'lit': 16,
#          'integration': 29,
#          'thanks': 231,
#          'todd_lash': 120,
#          'visionsbyvic': 13,
#          'interesting': 14,
#          'programming': 101,
#          'eric': 3,
#          'brown': 3,
#          'carnegie': 7,
#          'mellon': 7,
#          'yep': 5,
#          'online': 30,
#          'stop': 127,
#          '21': 12,
#          'mindtap': 9,
#          'help': 126,
#          'yo': 3,
#          'google': 112,
#          'translate': 11,
#          'getting': 99,
#          'excited': 271,
#          'try': 23,
#          'interactive': 15,
#          'telling': 3,
#          'w': 59,
#          'unfold': 3,
#          'studio': 5,
#          'sharing': 78,
#          'awesome': 154,
#          'morning': 119,
#          'vr': 64,
#          'aframevr': 18,
#          'build': 43,
#          'app': 55,
#          'tell': 26,
#          'pizza': 11,
#          '12': 89,
#          'framework': 5,
#          'states': 14,
#          'practice': 15,
#          'fostering': 11,
#          'inclusive': 22,
#          'culture': 9,
#          'see': 164,
#          'inspiredtoteach': 34,
#          'fgmart': 23,
#          'ireneannelee': 11,
#          'csteachersorg': 511,
#          'jovialjoy': 3,
#          'nytimes': 3,
#          'ajlunited': 3,
#          'sound': 5,
#          'mis': 3,
#          'tliandrew': 11,
#          'things': 86,
#          'graphing': 15,
#          'circuitplayground': 14,
#          'accelerometer': 14,
#          'adafruit': 33,
#          'neopixel': 14,
#          'strip': 14,
#          'csta201': 26,
#          'j_alano': 7,
#          'session': 246,
#          'czajka_sandy': 16,
#          'crystallfurman': 15,
#          'objects': 12,
#          'always': 13,
#          'looking': 155,
#          'snap': 4,
#          'based': 57,
#          'allows': 5,
#          'distributed': 4,
#          'aderbenwick': 48,
#          'cseducation': 18,
#          'teaching': 168,
#          'kids': 50,
#          'data': 142,
#          'oracle': 19,
#          'dev': 6,
#          'gym': 6,
#          'free': 38,
#          'btwarek': 115,
#          'pumped': 23,
#          'billmarsland': 117,
#          'visionsbyvicky': 166,
#          'literacy': 41,
#          'amazing': 162,
#          'cool': 46,
#          'attendees': 59,
#          'got': 68,
#          'sneak': 8,
#          'preview': 10,
#          'coming': 41,
#          'fall': 13,
#          'miss': 33,
#          'super': 34,
#          'panel': 11,
#          'content': 16,
#          'coaching': 47,
#          'monday': 24,
#          '11': 36,
#          '15': 69,
#          'room': 75,
#          '210': 18,
#          'tomorrow': 71,
#          'greenescience': 26,
#          'watershed': 22,
#          'moment': 28,
#          'chris': 32,
#          'jakebask': 172,
#          'reception': 45,
#          'derekbabb': 52,
#          'made': 70,
#          'fun': 114,
#          'sheet': 37,
#          'people': 101,
#          'c': 126,
#          'debrajacoby': 3,
#          'missing': 12,
#          'jigsawing': 14,
#          'writing': 23,
#          'standards': 17,
#          'aligned': 18,
#          'concepts': 21,
#          'book': 40,
#          'graduatefromblocks': 17,
#          'codespace': 53,
#          'csk8': 229,
#          'map': 3,
#          'zoom': 3,
#          'pan': 3,
#          'give': 18,
#          'city': 12,
#          'weather': 5,
#          'possibilities': 12,
#          'program': 87,
#          'scratch': 147,
#          'csta': 348,
#          'today': 134,
#          'meet': 73,
#          'lea': 11,
#          'evelyn': 9,
#          'team': 35,
#          'readwritecode': 12,
#          'teachmecs': 42,
#          'supersad': 6,
#          'instance': 6,
#          'emoji': 38,
#          'newest': 7,
#          'classroom': 80,
#          'even': 21,
#          'easier': 6,
#          'set': 10,
#          'studen': 5,
#          'wrapped': 25,
#          'summit': 45,
#          '70': 25,
#          'chapter': 84,
#          'leaders': 79,
#          'across': 46,
#          'us': 182,
#          'proud': 54,
#          'teachers': 375,
#          'leslie': 10,
#          'keller': 8,
#          'aced': 5,
#          'microsoftmta': 44,
#          'another': 35,
#          'person': 5,
#          'passes': 5,
#          'certification': 24,
#          'passedmymta': 70,
#          'addicting': 3,
#          'play': 26,
#          'observation': 10,
#          'emph': 3,
#          'sandcas': 3,
#          'taegot': 11,
#          'codenewbies': 9,
#          'a2': 11,
#          'week': 70,
#          'attending': 36,
#          'goal': 42,
#          'gain': 18,
#          'skills': 17,
#          'applied': 9,
#          'toolki': 6,
#          'would': 64,
#          'share': 52,
#          'contact': 11,
#          'information': 28,
#          'nailed': 3,
#          'left': 12,
#          'came': 10,
#          'job': 23,
#          'deserve': 3,
#          'congratul': 3,
#          'm4ttbit': 48,
#          'firial': 7,
#          'mrtomocon': 63,
#          'weareci': 15,
#          'action': 35,
#          'st': 44,
#          'scholastica': 3,
#          '36': 3,
#          '2': 46,
#          'greet': 3,
#          'spent': 15,
#          'creating': 40,
#          '3d': 32,
#          'threejs': 10,
#          'npmjs': 10,
#          'gr8': 8,
#          'stu': 3,
#          'bruce': 5,
#          'philly': 15,
#          '202': 18,
#          'cer': 3,
#          'launchcompsci': 30,
#          'infusing': 14,
#          'started': 50,
#          'quick': 11,
#          'sql': 7,
#          'anyone': 19,
#          'else': 16,
#          'around': 8,
#          'speak': 4,
#          'language': 29,
#          'booleans': 3,
#          'strings': 3,
#          'classes': 24,
#          'oop': 11,
#          'dkiang': 6,
#          'jaqster': 8,
#          'microsoftedu': 26,
#          'honor': 12,
#          'proctor': 5,
#          'stanford': 5,
#          'transformative': 5,
#          'technologies': 7,
#          'less': 14,
#          'recognising': 5,
#          'drawings': 5,
#          'done': 15,
#          'handed': 5,
#          'prejudice': 5,
#          'zgalant': 3,
#          'time': 114,
#          'courses': 4,
#          'day': 140,
#          'national': 19,
#          'aef_program': 5,
#          'opportun': 3,
#          'th': 33,
#          'workshops': 25,
#          'dark': 3,
#          'least': 4,
#          'illuminating': 3,
#          'systems': 13,
#          'patterns': 8,
#          'machinelearning': 6,
#          'patricia': 3,
#          'completed': 13,
#          'database': 7,
#          'fundamentals': 4,
#          'home': 18,
#          'certi': 5,
#          'one': 135,
#          'slide': 7,
#          'katherine': 3,
#          'wittig': 3,
#          'completes': 3,
#          'java': 8,
#          'certiport': 63,
#          'cs4me': 33,
#          'cs4all': 35,
#          'maine': 17,
#          'digging': 8,
#          'folks': 37,
#          'bit': 24,
#          'nsf': 12,
#          'rocks': 18,
#          'special': 17,
#          'prize': 23,
#          'wa': 9,
#          'daniel': 13,
#          'schneider': 9,
#          'html': 13,
#          'boom': 5,
#          'course': 23,
#          'le': 13,
#          'woo': 9,
#          'hoo': 7,
#          'spectacular': 3,
#          'view': 3,
#          'skybridge': 5,
#          'gorgeous': 3,
#          'pati_ru': 12,
#          'heading': 88,
#          'present': 20,
#          'ways': 16,
#          'encourage': 14,
#          'young': 15,
#          'women': 10,
#          'urm': 8,
#          'participate': 9,
#          'eng': 10,
#          'tues': 12,
#          '206': 9,
#          '207': 9,
#          'computerscience': 24,
#          'project': 27,
#          'arcade': 6,
#          'game': 46,
#          'builder': 3,
#          'make': 205,
#          'makecode': 5,
#          'seetryfly': 12,
#          'object': 6,
#          'oriented': 6,
#          'toys': 16,
#          'stscholastica': 15,
#          'thank': 185,
#          'cherry': 3,
#          'lucarelli': 3,
#          'neilplotnick': 20,
#          'local': 30,
#          'chapters': 12,
#          'host': 7,
#          'competitions': 10,
#          'csforalltchrs': 81,
#          'investigations': 8,
#          'csta18': 33,
#          'und': 6,
#          'johnphamous': 5,
#          'github': 7,
#          'stickers': 22,
#          'homes': 6,
#          'kristeenshabram': 52,
#          'calling': 30,
#          '8': 60,
#          'hang': 44,
#          'sunday': 40,
#          'night': 41,
#          '7': 52,
#          '30pm': 33,
#          'hilton': 56,
#          'lobby': 44,
#          'landed': 10,
#          'nerd': 6,
#          'cps': 3,
#          'opportunity': 21,
#          'connect': 54,
#          'swap': 14,
#          'stories': 24,
#          'twitter': 44,
#          'handles': 14,
#          'grow': 14,
#          'pln': 16,
#          'roger': 10,
#          'jaffe': 9,
#          'eye': 3,
#          'opening': 23,
#          'environments': 9,
#          'tons': 13,
#          'product': 8,
#          'launched': 6,
#          'march': 8,
#          'committed': 12,
#          'according': 9,
#          'n': 5,
#          'chat': 105,
#          'cs4allcps': 33,
#          'members': 86,
#          'checked': 8,
#          'little': 26,
#          'relaxat': 3,
#          'collaboration': 6,
#          'go': 31,
#          'group': 93,
#          'dedicated': 7,
#          'trying': 7,
#          'improve': 8,
#          'blake': 8,
#          'cook': 3,
#          'represent': 14,
#          'alabama': 13,
#          'roll': 8,
#          'tide': 3,
#          'afunabiki': 7,
#          'ocpdmusic': 7,
#          'volunteering': 7,
#          'awesomegenie': 19,
#          'pi': 31,
#          'champions': 11,
#          'facili': 9,
#          'inspired': 20,
#          'country': 11,
#          'fro': 5,
#          'sighting': 3,
#          'stuff': 48,
#          'indeed': 3,
#          'eager': 3,
#          'next': 71,
#          'three': 17,
#          'days': 19,
#          'forward': 103,
#          'gender': 48,
#          'inclusion': 26,
#          'rolling': 3,
#          'dice': 3,
#          'p5': 19,
#          'js': 19,
#          'sure': 84,
#          'bootstrap': 49,
#          'mit': 5,
#          'appinventor': 3,
#          'ios': 5,
#          'end': 10,
#          'jill': 3,
#          'thompson': 3,
#          'passed': 25,
#          'testing': 35,
#          'lab': 23,
#          'psyched': 3,
#          'simple': 5,
#          'virtual': 16,
#          'reality': 16,
#          'chibitronics': 66,
#          'aaaaaand': 5,
#          'coffee': 12,
#          'might': 15,
#          'helpful': 14,
#          'soon': 12,
#          'educ': 3,
#          'certified': 5,
#          'pass': 9,
#          'cert': 14,
#          'begins': 4,
#          'circuit': 16,
#          'neopixels': 11,
#          'shooting': 3,
#          'score': 3,
#          'yet': 26,
#          'mowenlibrarian': 17,
#          'loving': 18,
#          'ok': 9,
#          'lot': 55,
#          'kiddos': 7,
#          '_hfesowls': 9,
#          'bryantschools': 7,
#          'minecraft': 7,
#          'arkidscancode': 84,
#          'csforar': 88,
#          'anthonyowenade': 61,
#          'kennethjulian': 3,
#          'latinagirlscode': 3,
#          'blue1647': 3,
#          'leontynesjr': 7,
#          'karrinburns': 5,
#          'appleedu': 13,
#          'apple': 17,
#          'distinguished': 7,
#          'everyonecancode': 9,
#          'number': 8,
#          '23': 5,
#          'critical': 9,
#          'digitalskills': 5,
#          'children': 5,
#          'wha': 3,
#          'sphsphsphsph': 12,
#          'vital': 10,
#          'early': 43,
#          'relevant': 14,
#          'interests': 12,
#          'csfirst': 116,
#          'sci': 4,
#          'chibiclip': 11,
#          '_kimberly_p': 48,
#          'bxvtech': 42,
#          'makered': 9,
#          'aframe': 8,
#          'tweets': 11,
#          'looks': 19,
#          'remains': 2,
#          'sadly': 2,
#          'oblivious': 2,
#          'state': 58,
#          'never': 13,
#          'achi': 2,
#          'ed_saber': 99,
#          'want': 53,
#          'stand': 13,
#          'hate': 14,
#          'congressionalac': 13,
#          'wishing': 8,
#          'excellent': 11,
#          'weekend': 18,
#          'coaches': 21,
#          'mentors': 20,
#          'grateful': 15,
#          'csteach': 9,
#          'bring': 29,
#          'web': 2,
#          'platform': 2,
#          'quickly': 3,
#          'create': 57,
#          'des': 2,
#          'stoked': 12,
#          '2018': 89,
#          'affiliate': 10,
#          'ton': 12,
#          'certscott': 38,
#          'rebekahclang': 18,
#          'wow': 46,
#          'rebekah': 14,
#          'two': 36,
#          'exams': 16,
#          'hankering': 4,
#          'icecream': 4,
#          'coneflowercreamery': 4,
#          'hotnessss': 4,
#          'dougbergmanusa': 44,
#          'picademy': 26,
#          'birv2': 25,
#          'ascollins': 24,
#          'raspberry': 18,
#          'applications': 10,
#          'follow': 41,
#          'codinginthewild': 6,
#          'readwrit': 4,
#          'arduino': 59,
#          'chibicsta18': 14,
#          'designing': 5,
#          'lessons': 22,
#          'alfredtwo': 59,
#          'desk': 4,
#          'paper': 14,
#          'circuits': 11,
#          'qijie': 11,
#          'eilatann': 14,
#          'terriebrown17': 2,
#          'soil': 4,
#          'moisture': 4,
#          'micro': 10,
#          'bpsne': 5,
#          'saturday': 10,
#          'succesfully': 8,
#          'serial': 8,
#          'mac': 8,
#          'endless': 8,
#          'middl': 8,
#          'increased': 2,
#          'ss': 23,
#          'tools': 28,
#          'wrenchey': 11,
#          'favorite': 20,
#          'monthly': 4,
#          'magazine': 6,
#          '4': 56,
#          'raspberry_pi': 24,
#          'kit': 14,
#          'matthew': 18,
#          'cheng': 18,
#          'naming': 2,
#          'variables': 2,
#          'emphasise': 2,
#          'sense': 2,
#          'oth': 2,
#          'minecraftedu': 12,
#          '20': 48,
#          'mo': 2,
#          'ctak10': 11,
#          'ct': 6,
#          'teachcs': 4,
#          'fabulous': 5,
#          'stations': 5,
#          'centurylink': 2,
#          'center': 11,
#          'crafting': 3,
#          'added': 4,
#          'motor': 4,
#          'microbit_edu': 47,
#          'ms_deljuidice': 33,
#          'ch': 4,
#          'zsearels': 2,
#          'exciting': 17,
#          'enjoying': 10,
#          'inventor': 16,
#          'android': 3,
#          'apps': 9,
#          'lighting': 10,
#          'smileybantam': 8,
#          'thecseducator': 43,
#          'jvadenbarth': 8,
#          'conferences': 7,
#          'appreciation': 8,
#          'terryfosterjr': 6,
#          'huh': 3,
#          'last': 30,
#          'united': 2,
#          'flights': 4,
#          'hours': 9,
#          'late': 2,
#          '13': 10,
#          'den': 3,
#          'sfo': 2,
#          'hoping': 5,
#          'third': 10,
#          'better': 23,
#          'watch': 10,
#          'sesamestreet': 8,
#          'waiting': 10,
#          'talk': 76,
#          'computationalthinking': 24,
#          'csf': 6,
#          'success': 3,
#          'century': 4,
#          'jersey': 2,
#          'showing': 8,
#          'g': 20,
#          'tricks': 2,
#          'ha': 4,
#          'kkuhlers': 10,
#          'csteache': 9,
#          'kyjo41': 5,
#          'kick': 8,
#          'bmilonovich': 11,
#          'thoughts': 12,
#          'cyber': 17,
#          'security': 17,
#          'visual': 11,
#          'meechele7': 12,
#          'cybersecurity': 19,
#          'mean': 19,
#          'cstasnj': 25,
#          'csnj': 30,
#          'registration': 9,
#          'station': 2,
#          'tutorial': 2,
#          'diving': 12,
#          'frame': 2,
#          'world': 44,
#          'grass': 3,
#          'tree': 6,
#          'higher': 4,
#          'version': 8,
#          'math': 21,
#          'mr_segen': 4,
#          'middle': 45,
#          'schooler': 7,
#          'also': 33,
#          'en': 6,
#          'route': 6,
#          'london': 4,
#          'canada': 2,
#          'yxu': 2,
#          'yyz': 2,
#          'oma': 4,
#          'd_sedlar': 2,
#          'heard': 11,
#          'sorry': 2,
#          'missed': 3,
#          'yesterday': 4,
#          'head': 21,
#          'headed': 33,
#          'hello': 43,
#          'pick': 18,
#          'swag': 90,
#          'bla': 2,
#          'unplug': 19,
#          'computational': 97,
#          '6': 5,
#          '00': 14,
#          'flight': 8,
#          '51': 6,
#          'friends': 97,
#          'lhetechnology': 2,
#          'important': 50,
#          'message': 4,
#          'setting': 6,
#          'educator': 27,
#          'heroes': 19,
#          '25': 16,
#          'democratising': 2,
#          'run': 34,
#          'updates': 4,
#          'hands': 26,
#          'microsoft': 146,
#          'conversations': 8,
#          'administration': 2,
#          'school': 91,
#          'teach': 26,
#          'credentials': 4,
#          'attained': 4,
#          'plus': 15,
#          'bag': 17,
#          'full': 33,
#          'stchar': 2,
#          'common': 6,
#          'frustrations': 2,
#          'may': 3,
#          'network': 6,
#          'protocols': 2,
#          'pla': 2,
#          'sitting': 2,
#          'lady': 10,
#          'sees': 2,
#          'straightouttacampos': 2,
#          'sticker': 31,
#          'routing': 3,
#          'unplugged': 5,
#          'manip': 2,
#          'craft': 3,
#          'meets': 3,
#          'tinkering': 3,
#          'starting': 36,
#          'papert': 8,
#          'lego': 4,
#          'seymour': 2,
#          'featured': 2,
#          'mitappinventor': 2,
#          'bright': 4,
#          'oascholar': 6,
#          'bvwbirnbaum': 2,
#          'duties': 2,
#          'thisisamerica': 6,
#          'immaturegambino': 4,
#          'gearing': 3,
#          'pre': 7,
#          'service': 5,
#          'cstanebraska': 4,
#          'walk': 3,
#          'culprit': 2,
#          'routine': 2,
#          'beignet': 2,
#          'wi': 4,
#          'unpack': 2,
#          'beside': 2,
#          'cspbjc': 2,
#          'birdbraintech': 12,
#          'retreat': 2,
#          'planning': 14,
#          'beyond': 11,
#          'ti': 2,
#          'csforallnyc': 19,
#          'leading': 18,
#          'p5xjs': 14,
#          'creativecoding': 14,
#          'attended': 16,
#          'kagen': 2,
#          'cooperative': 6,
#          'answers': 4,
#          'panelists': 2,
#          'promote': 14,
#          'increase': 12,
#          'jennifer_manly': 22,
#          'jazzed': 4,
#          '3': 37,
#          '30': 22,
#          'beyo': 2,
#          'bestlessonever': 4,
#          'part': 35,
#          'tuesday': 11,
#          'nifty': 4,
#          'assignments': 4,
#          '215': 4,
#          'goggle': 1,
#          'contribution': 3,
#          'administrators': 6,
#          'chibi': 4,
#          'chip': 4,
#          'starter': 8,
#          'han': 2,
#          'ask': 32,
#          'interact': 10,
#          'built': 10,
#          'fairly': 10,
#          'mr_isaacs': 2,
#          'scratched': 4,
#          'dana_augustin': 4,
#          'bi': 2,
#          'learned': 29,
#          'representing': 61,
#          'dozen': 10,
#          'professor': 17,
#          'jgrayatua': 10,
#          'decided': 2,
#          'capture': 2,
#          'image': 2,
#          'unique': 5,
#          'circus': 2,
#          'enjoy': 7,
#          'jump': 2,
#          'due': 21,
#          'overwhelming': 21,
#          'participation': 22,
#          'reached': 21,
#          'max': 26,
#          'met': 29,
#          'wonderful': 12,
#          'wait': 65,
#          'geek': 14,
#          'geekery': 6,
#          'bx': 4,
#          'east': 3,
#          'coasters': 2,
#          'forget': 8,
#          'travel': 6,
#          'alarm': 6,
#          'clocks': 2,
#          'back': 37,
#          'doe': 2,
#          'bringing': 20,
#          'ideas': 36,
#          'wanting': 6,
#          'celebrate': 7,
#          'sept': 4,
#          '12th': 4,
#          'training': 9,
#          'csforkids': 4,
#          'mharveytech': 27,
#          'mention': 6,
#          'selfies': 6,
#          ...})

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import random

# %%
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

# %%
mask = np.array(Image.open('./mona.jpg'))

words = ' '.join(word for word in filtered_tokens)
wordcloud = WordCloud(
    background_color='black',
    scale=10,
    mask=mask
).generate(words)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud.recolor(color_func=grey_color_func, random_state=1), interpolation='bilinear')
plt.tight_layout()
plt.axis("off")
plt.savefig('./word_cloud.png', bbox_inches='tight')
