# %%
import pandas as pd
import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tweets = pd.read_csv('./csta.csv', names=['date', 'tweet'], encoding='utf8')

# %%
tweets['date'] = pd.to_datetime(tweets['date'])
tweets['tweet'] = tweets['tweet'].astype(str)

# %%
retweets = tweets[tweets['tweet'].str.contains('RT')]

# %%
tweets['is_retweet'] = tweets['tweet'].apply(lambda t: t if 'RT' in t else 0)

# %%
new_col = []
for tweet in tweets['is_retweet']:
    if tweet is not 0:
        new_col.append('Retweet')
    else:
        new_col.append('Original')
tweets['is_retweet'] = new_col

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="is_retweet", data=tweets, )
ax.set_title('#CSTA2018 Retweets vs. Unique (July 8, 2018 3:25PM)')
ax.set_xlabel('Type of Tweet')
ax.set_ylabel('Number of Tweets')
figure = ax.get_figure()
figure.savefig('retweets.jpg')

# %%
tweets['date'].iloc[0].hour
# Out:
# 19

# %%
time_series = tweets.groupby(
    [pd.Grouper(key='date',freq='H')]
).size().reset_index(name='count')

# %%
time_series
# Out:
#                    date  count
# 0   2018-06-29 14:00:00      3
# 1   2018-06-29 15:00:00      2
# 2   2018-06-29 16:00:00      3
# 3   2018-06-29 17:00:00      1
# 4   2018-06-29 18:00:00      1
# 5   2018-06-29 19:00:00      1
# 6   2018-06-29 20:00:00      2
# 7   2018-06-29 21:00:00      0
# 8   2018-06-29 22:00:00      3
# 9   2018-06-29 23:00:00      0
# 10  2018-06-30 00:00:00      0
# 11  2018-06-30 01:00:00      3
# 12  2018-06-30 02:00:00      0
# 13  2018-06-30 03:00:00      1
# 14  2018-06-30 04:00:00      1
# 15  2018-06-30 05:00:00      0
# 16  2018-06-30 06:00:00      0
# 17  2018-06-30 07:00:00      0
# 18  2018-06-30 08:00:00      0
# 19  2018-06-30 09:00:00      0
# 20  2018-06-30 10:00:00      0
# 21  2018-06-30 11:00:00      1
# 22  2018-06-30 12:00:00      0
# 23  2018-06-30 13:00:00     13
# 24  2018-06-30 14:00:00      7
# 25  2018-06-30 15:00:00      1
# 26  2018-06-30 16:00:00      1
# 27  2018-06-30 17:00:00      0
# 28  2018-06-30 18:00:00      1
# 29  2018-06-30 19:00:00      1
# ..                  ...    ...
# 192 2018-07-07 14:00:00     16
# 193 2018-07-07 15:00:00     17
# 194 2018-07-07 16:00:00     11
# 195 2018-07-07 17:00:00     13
# 196 2018-07-07 18:00:00     33
# 197 2018-07-07 19:00:00     43
# 198 2018-07-07 20:00:00     37
# 199 2018-07-07 21:00:00     31
# 200 2018-07-07 22:00:00     29
# 201 2018-07-07 23:00:00     15
# 202 2018-07-08 00:00:00     26
# 203 2018-07-08 01:00:00     10
# 204 2018-07-08 02:00:00     14
# 205 2018-07-08 03:00:00     14
# 206 2018-07-08 04:00:00     11
# 207 2018-07-08 05:00:00      2
# 208 2018-07-08 06:00:00      4
# 209 2018-07-08 07:00:00      2
# 210 2018-07-08 08:00:00      0
# 211 2018-07-08 09:00:00      1
# 212 2018-07-08 10:00:00      1
# 213 2018-07-08 11:00:00      8
# 214 2018-07-08 12:00:00     11
# 215 2018-07-08 13:00:00     24
# 216 2018-07-08 14:00:00     33
# 217 2018-07-08 15:00:00     70
# 218 2018-07-08 16:00:00     53
# 219 2018-07-08 17:00:00     27
# 220 2018-07-08 18:00:00     82
# 221 2018-07-08 19:00:00     66
#
# [222 rows x 2 columns]

# %%
ax = time_series.plot(x='date', y='count', figsize=(20, 7))
ax.axvline(x='2018-07-07 10:00:00', color='red', label='Start')
ax.text(x='2018-07-07 12:30:00', y=60, s='CSTA Start', fontsize=20)
sns.set_style('darkgrid')
ax.set_title('Twitter Activity by Time (Up to July 8 4:44PM)')
ax.set_xlabel('Day and Hour')
ax.set_ylabel('Number of Tweets')
figure = ax.get_figure()
figure.savefig('timeseries.jpg')
# plt.show()
